# %% [markdown]
# # Testing NCBI hg38.p14 GTF file

# %% [markdown]
# *Anusha Aggarwal*

# %%
import numpy as np
import pandas as pd
from tqdm import tqdm
tqdm.pandas()
import re
import os
from pyfaidx import Fasta
from Bio.Seq import Seq

# %%
gtf_cds = pd.read_csv('/mnt/home/aaggarwal/ceph/gates_proj/ncbi_genome_hg38.p14/hg38.p14.ncbiRefSeq.CDS_final_gtf.csv')
gtf_trans = pd.read_csv('/mnt/home/aaggarwal/ceph/gates_proj/ncbi_genome_hg38.p14/hg38.p14.ncbiRefSeq.transcript_final_gtf.csv')

# %%
gtf_cds
# Out:
#        seqname      source      feature     start       end score strand  \
# 0         chr1  BestRefSeq          CDS     65565     65573     .      +
# 1         chr1  BestRefSeq          CDS     69037     70005     .      +
# 2         chr1  BestRefSeq  start_codon     65565     65567     .      +
# 3         chr1  BestRefSeq   stop_codon     70006     70008     .      +
# 4         chr1  BestRefSeq          CDS    450743    451678     .      -
# ...        ...         ...          ...       ...       ...   ...    ...
# 229586    chrY  BestRefSeq   stop_codon  25038098  25038100     .      -
# 229587    chrY  BestRefSeq          CDS  25622443  25624034     .      +
# 229588    chrY  BestRefSeq          CDS  25624455  25624524     .      +
# 229589    chrY  BestRefSeq  start_codon  25622443  25622445     .      +
# 229590    chrY  BestRefSeq   stop_codon  25624525  25624527     .      +
#
#         frame                                         attributes gene_id  \
# 0           0  gene_id "OR4F5"; transcript_id "NM_001005484.2...   OR4F5
# 1           0  gene_id "OR4F5"; transcript_id "NM_001005484.2...   OR4F5
# 2           0  gene_id "OR4F5"; transcript_id "NM_001005484.2...   OR4F5
# 3           0  gene_id "OR4F5"; transcript_id "NM_001005484.2...   OR4F5
# 4           0  gene_id "OR4F29"; transcript_id "NM_001005221....  OR4F29
# ...       ...                                                ...     ...
# 229586      0  gene_id "BPY2C"; transcript_id "NM_001002761.1...   BPY2C
# 229587      0  gene_id "CDY1"; transcript_id "NM_004680.3"; d...    CDY1
# 229588      1  gene_id "CDY1"; transcript_id "NM_004680.3"; d...    CDY1
# 229589      0  gene_id "CDY1"; transcript_id "NM_004680.3"; d...    CDY1
# 229590      0  gene_id "CDY1"; transcript_id "NM_004680.3"; d...    CDY1
#
#          transcript_id  entrez_id  length
# 0       NM_001005484.2      79501       9
# 1       NM_001005484.2      79501     969
# 2       NM_001005484.2      79501       3
# 3       NM_001005484.2      79501       3
# 4       NM_001005221.2     729759     936
# ...                ...        ...     ...
# 229586  NM_001002761.1     442868       3
# 229587     NM_004680.3       9085    1592
# 229588     NM_004680.3       9085      70
# 229589     NM_004680.3       9085       3
# 229590     NM_004680.3       9085       3
#
# [229591 rows x 13 columns]

# %%
gtf_trans
# Out:
#       seqname      source     feature     start       end score strand frame  \
# 0        chr1  BestRefSeq  transcript     65419     71585     .      +     .
# 1        chr1  BestRefSeq  transcript    450740    451678     .      -     .
# 2        chr1  BestRefSeq  transcript    685716    686654     .      -     .
# 3        chr1  BestRefSeq  transcript    923923    944574     .      +     .
# 4        chr1  BestRefSeq  transcript    944203    959256     .      -     .
# ...       ...         ...         ...       ...       ...   ...    ...   ...
# 19161    chrY  BestRefSeq  transcript  24618004  24639207     .      +     .
# 19162    chrY  BestRefSeq  transcript  24763069  24813393     .      -     .
# 19163    chrY  BestRefSeq  transcript  24833919  24907040     .      +     .
# 19164    chrY  BestRefSeq  transcript  25030901  25052104     .      -     .
# 19165    chrY  BestRefSeq  transcript  25622117  25624902     .      +     .
#
#                                               attributes gene_id  \
# 0      gene_id "OR4F5"; transcript_id "NM_001005484.2...   OR4F5
# 1      gene_id "OR4F29"; transcript_id "NM_001005221....  OR4F29
# 2      gene_id "OR4F16"; transcript_id "NM_001005277....  OR4F16
# 3      gene_id "SAMD11"; transcript_id "NM_001385641....  SAMD11
# 4      gene_id "NOC2L"; transcript_id "NM_015658.4"; ...   NOC2L
# ...                                                  ...     ...
# 19161  gene_id "BPY2B"; transcript_id "NM_001002760.1...   BPY2B
# 19162  gene_id "DAZ3"; transcript_id "NM_020364.4"; d...    DAZ3
# 19163  gene_id "DAZ4"; transcript_id "NM_001388484.1"...    DAZ4
# 19164  gene_id "BPY2C"; transcript_id "NM_001002761.1...   BPY2C
# 19165  gene_id "CDY1"; transcript_id "NM_004680.3"; d...    CDY1
#
#         transcript_id  entrez_id
# 0      NM_001005484.2      79501
# 1      NM_001005221.2     729759
# 2      NM_001005277.1      81399
# 3      NM_001385641.1     148398
# 4         NM_015658.4      26155
# ...               ...        ...
# 19161  NM_001002760.1     442867
# 19162     NM_020364.4      57054
# 19163  NM_001388484.1      57135
# 19164  NM_001002761.1     442868
# 19165     NM_004680.3       9085
#
# [19166 rows x 12 columns]

# %%
unique_gene_ids_count = gtf_cds["gene_id"].nunique()
unique_gene_ids_count
# Out:
# 19166

# %%
unique_gene_ids_count = gtf_cds["entrez_id"].nunique()
unique_gene_ids_count
# Out:
# 19166

# %%
gtf_transcripts["entrez_id"].nunique()
# Out:
# 19166

# %%
gtf_transcripts["transcript_id"].nunique()
# Out:
# 19166

# %%
def get_adjusted_cds_windows(transcript_id, chrom, strand, gtf_df):
    transcript_df = gtf_df[gtf_df['transcript_id'] == transcript_id]
    cds_df = transcript_df[transcript_df['feature'] == 'CDS']
    start_df = transcript_df[transcript_df['feature'] == 'start_codon']
    stop_df = transcript_df[transcript_df['feature'] == 'stop_codon']

    if cds_df.empty or start_df.empty or stop_df.empty:
        return None

    start_codon_start = start_df.iloc[0]['start']
    stop_codon_end = stop_df.iloc[0]['end']

    if strand == '+':
        cds_df = cds_df[
            (cds_df['end'] >= start_codon_start) &
            (cds_df['start'] <= stop_codon_end)
        ].sort_values(by='start')
    else:
        start_codon_end = start_df.iloc[0]['end']
        stop_codon_start = stop_df.iloc[0]['start']
    
        cds_df = cds_df[
            (cds_df['end'] >= stop_codon_start) &
            (cds_df['start'] <= start_codon_end)
        ].sort_values(by='end', ascending=False)

    if cds_df.empty:
        return None

    cds_windows = []
    for i, row in cds_df.iterrows():
        start = row['start']
        end = row['end']

        if strand == '+':
            if start <= start_codon_start <= end:
                start = start_codon_start
        else:
            if start <= start_codon_end <= end:
                end = start_codon_end

        if strand == '+':
            if start <= stop_codon_end <= end:
                end = stop_codon_end
        else:
            if start <= stop_codon_start <= end:
                start = stop_codon_start

        if end > start:
            cds_windows.append((start, end, int(row['frame'])))

    return cds_windows if cds_windows else None

# %%
gtf_cds[gtf_cds['entrez_id'] == 339456]

# %%
gtf_cds[gtf_cds['transcript_id'] == 'NM_014188.3']

# %%
windows = get_adjusted_cds_windows("NM_014188.3", "chr1", "-", gtf_cds)

# %%
windows

# %%
genome_fasta_dir = "/mnt/home/aaggarwal/ceph/gates_proj/ncbi_genome_hg38.p14"

# load the genome
fasta_files = {
    f.replace(".fa", ""): os.path.join(genome_fasta_dir, f)
    for f in os.listdir(genome_fasta_dir) if f.endswith(".fa")
}
fasta_index = {k: Fasta(v) for k, v in fasta_files.items()}

# %%
cds_windows = sorted(windows, key=lambda x: x[0], reverse=True)
cds_windows

# %%
genome = fasta_index['chr1']

# %%
chrom = genome['chr1']

# %%
seq_parts = []

# %%
for i, (start, end, frame) in enumerate(cds_windows):
    start = int(start)
    end = int(end)
    frame = int(frame)

    exon_seq = chrom[start-1:end].seq.upper()

    if i == 0:
        exon_seq = exon_seq[frame:]

    seq_parts.append(exon_seq)

# %%
full_seq = ''.join(seq_parts[::-1])  # reverse exon order
full_seq_rc = str(Seq(full_seq).reverse_complement())

# %%
protein = str(Seq(full_seq_rc).translate(to_stop=False))

# %%
print(f"First codon: {full_seq_rc[:3]}")
print(f"Protein start: {protein[:10]}")
print(f"Full protein: {protein}")

# %%
seq_parts = []
for i, (start, end, frame) in enumerate(cds_windows):
    start = int(start)
    end = int(end)
    frame = int(frame)

    exon_seq = chrom[start-1:end].seq.upper()

    exon_seq = exon_seq[frame:]

    seq_parts.append(exon_seq)

# %%
full_seq = ''.join(seq_parts[::-1])  # reverse exon order
full_seq_rc = str(Seq(full_seq).reverse_complement())

protein = str(Seq(full_seq_rc).translate(to_stop=False))

print(f"First codon: {full_seq_rc[:3]}")
print(f"Protein start: {protein[:10]}")
print(f"Full protein: {protein}")

# %% [markdown]
# ### check VCF file for variant stuff

# %%
import pandas as pd

# %%
def load_gtf(gtf_path):
    # load the GTF as pandas dataframe

    col_names = [
        "seqname", "source", "feature", "start", "end",
        "score", "strand", "frame", "attributes", "gene_id", "transcript_id", "entrez_id"
    ]
    
    gtf_df = pd.read_csv(gtf_path)

    return gtf_df

def load_vcf(vcf_path):
    # load the VCF file
    # works with ClinVar's VCF format

    with open(vcf_path, 'r') as f:
        for i, line in enumerate(f):
            if line.startswith("#CHROM"):
                header_line = line.strip().lstrip("#").split("\t")
                break

    # read using the header line as column names
    vcf_df = pd.read_csv(
        vcf_path,
        sep="\t",
        comment="#",
        names=header_line,
        dtype={"CHROM": str, "POS": int, "REF": str, "ALT": str}
    )

    #return vcf_df
    return vcf_df.sample(n=200, random_state=42).reset_index(drop=True) # CHANGE THIS BEFORE PUSHING FINAL VERSION

def extract_gene_regions(gtf_df):
    # filter to protein-coding genes and extract
    # - entrez id
    # - chrom
    # - tss
    # - gene start
    # - gene end

    entrez_id = gtf_df['entrez_id'].astype(str)
    chrom = gtf_df['seqname']
    strand = gtf_df['strand']
    tss = gtf_df['start'].where(strand == '+', gtf_df['end'])
    gene_start = gtf_df['start']
    gene_end = gtf_df['end']
    transcript_id = gtf_df['transcript_id']
    
    return zip(entrez_id, transcript_id, chrom, strand, tss, gene_start, gene_end)

# %%
def annotate_vcf_with_entrez(vcf_df, gtf_df):
    # for each variant in the vcf file, find which gene it falls in using the gtf file
    # returns a new VCF file with "entrez_id" column

    gtf_df = gtf_df.copy()
    gtf_df['seqname'] = gtf_df['seqname'].astype(str).str.replace('chr', '', regex=False)

    print(gtf_df.head)

    vcf_df = vcf_df.copy()
    vcf_df['entrez_id'] = None

    print(vcf_df.head)

    gene_regions = extract_gene_regions(gtf_df)

    for entrez_id, _, chrom, _, _, gene_start, gene_end in gene_regions:
        chrom = str(chrom)
        mask = (
            (vcf_df['CHROM'] == chrom) &
            (vcf_df['POS'] >= gene_start) & 
            (vcf_df['POS'] <= gene_end)
        )
        vcf_df.loc[mask, 'entrez_id'] = entrez_id

    return vcf_df[vcf_df['entrez_id'].notnull()].copy()

def build_variant_dict_by_entrez(annotated_vcf):
    # returns a dict: entrez_id --> list of (pos, ref, alt)
    # only applies variants for now, no indels (single bp substitution)

    variant_dict = {}
    for _, row in annotated_vcf.iterrows():
        eid = str(row['entrez_id'])
        pos = int(row['POS'])
        ref = row['REF']
        alt = row['ALT']
        if pd.isnull(ref) or pd.isnull(alt):
            continue

        # only keep variants (single bp substitutions) -- no indels
        if len(ref) == 1 and len(alt) == 1 and ref != '-' and alt != '-':
            variant_dict.setdefault(eid, []).append((pos, ref, alt))

    print(f"Total genes with variants: {len(variant_dict)}")
            
    return variant_dict

# %%
gtf_transcript_path = "/mnt/home/aaggarwal/ceph/gates_proj/ncbi_genome_hg38.p14/hg38.p14.ncbiRefSeq.transcript_final_gtf.csv"
gtf_cds_path = "/mnt/home/aaggarwal/ceph/gates_proj/ncbi_genome_hg38.p14/hg38.p14.ncbiRefSeq.CDS_final_gtf.csv"
vcf_path = "/mnt/home/aaggarwal/ceph/gates_proj/testing_protein_translation/vcf_files/clinvar_20250706.vcf"

# %%
# load GTF
gtf_transcripts = load_gtf(gtf_transcript_path)
gtf_cds = load_gtf(gtf_cds_path)

# get gene regions for transcripts
gene_regions = extract_gene_regions(gtf_transcripts)

# load VCF
vcf = load_vcf(vcf_path)

# filer the vcf to variants/indels in gene regions and organize the variants per gene
annotated_vcf = annotate_vcf_with_entrez(vcf, gtf_transcripts)
variant_dict = build_variant_dict_by_entrez(annotated_vcf)
# Out:
# <bound method NDFrame.head of       seqname      source     feature     start       end score strand frame  \
# 0           1  BestRefSeq  transcript     65419     71585     .      +     .
# 1           1  BestRefSeq  transcript    450740    451678     .      -     .
# 2           1  BestRefSeq  transcript    685716    686654     .      -     .
# 3           1  BestRefSeq  transcript    923923    944574     .      +     .
# 4           1  BestRefSeq  transcript    944203    959256     .      -     .
# ...       ...         ...         ...       ...       ...   ...    ...   ...
# 19161       Y  BestRefSeq  transcript  24618004  24639207     .      +     .
# 19162       Y  BestRefSeq  transcript  24763069  24813393     .      -     .
# 19163       Y  BestRefSeq  transcript  24833919  24907040     .      +     .
# 19164       Y  BestRefSeq  transcript  25030901  25052104     .      -     .
# 19165       Y  BestRefSeq  transcript  25622117  25624902     .      +     .
#
#                                               attributes gene_id  \
# 0      gene_id "OR4F5"; transcript_id "NM_001005484.2...   OR4F5
# 1      gene_id "OR4F29"; transcript_id "NM_001005221....  OR4F29
# 2      gene_id "OR4F16"; transcript_id "NM_001005277....  OR4F16
# 3      gene_id "SAMD11"; transcript_id "NM_001385641....  SAMD11
# 4      gene_id "NOC2L"; transcript_id "NM_015658.4"; ...   NOC2L
# ...                                                  ...     ...
# 19161  gene_id "BPY2B"; transcript_id "NM_001002760.1...   BPY2B
# 19162  gene_id "DAZ3"; transcript_id "NM_020364.4"; d...    DAZ3
# 19163  gene_id "DAZ4"; transcript_id "NM_001388484.1"...    DAZ4
# 19164  gene_id "BPY2C"; transcript_id "NM_001002761.1...   BPY2C
# 19165  gene_id "CDY1"; transcript_id "NM_004680.3"; d...    CDY1
#
#         transcript_id  entrez_id
# 0      NM_001005484.2      79501
# 1      NM_001005221.2     729759
# 2      NM_001005277.1      81399
# 3      NM_001385641.1     148398
# 4         NM_015658.4      26155
# ...               ...        ...
# 19161  NM_001002760.1     442867
# 19162     NM_020364.4      57054
# 19163  NM_001388484.1      57135
# 19164  NM_001002761.1     442868
# 19165     NM_004680.3       9085
#
# [19166 rows x 12 columns]>
# <bound method NDFrame.head of     CHROM        POS       ID REF  ALT QUAL FILTER  \
# 0      19   11105435   403631   T    C    .      .
# 1       9   69246766  1285612   A  AGC    .      .
# 2      22   36326590  2956629   G    A    .      .
# 3      22   23825408   660223   G    A    .      .
# 4      11   83962925  2664635   G    C    .      .
# ..    ...        ...      ...  ..  ...  ...    ...
# 195     1  228165978   385811   C    T    .      .
# 196    19   58511443  2968972   G    A    .      .
# 197    17   28735261  2444833   A    T    .      .
# 198    17    6690880   541961   C    G    .      .
# 199    18   28013831  2987905   T    C    .      .
#
#                                                   INFO entrez_id
# 0    ALLELEID=390612;CLNDISDB=MONDO:MONDO:0007750,M...      None
# 1    ALLELEID=1275454;CLNDISDB=MONDO:MONDO:0014381,...      None
# 2    AF_EXAC=0.00002;ALLELEID=3115683;CLNDISDB=MedG...      None
# 3    ALLELEID=649228;CLNDISDB=MedGen:C3661900|MONDO...      None
# 4    AF_EXAC=0.00007;AF_TGP=0.00060;ALLELEID=283208...      None
# ..                                                 ...       ...
# 195  AF_EXAC=0.00000;ALLELEID=364876;CLNDISDB=MedGe...      None
# 196  ALLELEID=3135347;CLNDISDB=MedGen:C3661900;CLND...      None
# 197  ALLELEID=2418563;CLNDISDB=MONDO:MONDO:0013444,...      None
# 198  ALLELEID=531695;CLNDISDB=MONDO:MONDO:0014392,M...      None
# 199  AF_ESP=0.00008;AF_EXAC=0.00001;ALLELEID=314692...      None
#
# [200 rows x 9 columns]>
# Total genes with variants: 169

# %%
annotated_vcf
# Out:
#     CHROM        POS       ID REF  ALT QUAL FILTER  \
# 0      19   11105435   403631   T    C    .      .
# 1       9   69246766  1285612   A  AGC    .      .
# 2      22   36326590  2956629   G    A    .      .
# 3      22   23825408   660223   G    A    .      .
# 4      11   83962925  2664635   G    C    .      .
# ..    ...        ...      ...  ..  ...  ...    ...
# 195     1  228165978   385811   C    T    .      .
# 196    19   58511443  2968972   G    A    .      .
# 197    17   28735261  2444833   A    T    .      .
# 198    17    6690880   541961   C    G    .      .
# 199    18   28013831  2987905   T    C    .      .
#
#                                                   INFO entrez_id
# 0    ALLELEID=390612;CLNDISDB=MONDO:MONDO:0007750,M...      3949
# 1    ALLELEID=1275454;CLNDISDB=MONDO:MONDO:0014381,...      9414
# 2    AF_EXAC=0.00002;ALLELEID=3115683;CLNDISDB=MedG...      4627
# 3    ALLELEID=649228;CLNDISDB=MedGen:C3661900|MONDO...      6598
# 4    AF_EXAC=0.00007;AF_TGP=0.00060;ALLELEID=283208...      1740
# ..                                                 ...       ...
# 195  AF_EXAC=0.00000;ALLELEID=364876;CLNDISDB=MedGe...    200205
# 196  ALLELEID=3135347;CLNDISDB=MedGen:C3661900;CLND...     10998
# 197  ALLELEID=2418563;CLNDISDB=MONDO:MONDO:0013444,...    284086
# 198  ALLELEID=531695;CLNDISDB=MONDO:MONDO:0014392,M...    284111
# 199  AF_ESP=0.00008;AF_EXAC=0.00001;ALLELEID=314692...      1000
#
# [197 rows x 9 columns]

# %%
vcf
# Out:
#     CHROM        POS       ID REF  ALT QUAL FILTER  \
# 0      19   11105435   403631   T    C    .      .
# 1       9   69246766  1285612   A  AGC    .      .
# 2      22   36326590  2956629   G    A    .      .
# 3      22   23825408   660223   G    A    .      .
# 4      11   83962925  2664635   G    C    .      .
# ..    ...        ...      ...  ..  ...  ...    ...
# 195     1  228165978   385811   C    T    .      .
# 196    19   58511443  2968972   G    A    .      .
# 197    17   28735261  2444833   A    T    .      .
# 198    17    6690880   541961   C    G    .      .
# 199    18   28013831  2987905   T    C    .      .
#
#                                                   INFO
# 0    ALLELEID=390612;CLNDISDB=MONDO:MONDO:0007750,M...
# 1    ALLELEID=1275454;CLNDISDB=MONDO:MONDO:0014381,...
# 2    AF_EXAC=0.00002;ALLELEID=3115683;CLNDISDB=MedG...
# 3    ALLELEID=649228;CLNDISDB=MedGen:C3661900|MONDO...
# 4    AF_EXAC=0.00007;AF_TGP=0.00060;ALLELEID=283208...
# ..                                                 ...
# 195  AF_EXAC=0.00000;ALLELEID=364876;CLNDISDB=MedGe...
# 196  ALLELEID=3135347;CLNDISDB=MedGen:C3661900;CLND...
# 197  ALLELEID=2418563;CLNDISDB=MONDO:MONDO:0013444,...
# 198  ALLELEID=531695;CLNDISDB=MONDO:MONDO:0014392,M...
# 199  AF_ESP=0.00008;AF_EXAC=0.00001;ALLELEID=314692...
#
# [200 rows x 8 columns]

# %%
gtf_transcripts
# Out:
#       seqname      source     feature     start       end score strand frame  \
# 0        chr1  BestRefSeq  transcript     65419     71585     .      +     .
# 1        chr1  BestRefSeq  transcript    450740    451678     .      -     .
# 2        chr1  BestRefSeq  transcript    685716    686654     .      -     .
# 3        chr1  BestRefSeq  transcript    923923    944574     .      +     .
# 4        chr1  BestRefSeq  transcript    944203    959256     .      -     .
# ...       ...         ...         ...       ...       ...   ...    ...   ...
# 19161    chrY  BestRefSeq  transcript  24618004  24639207     .      +     .
# 19162    chrY  BestRefSeq  transcript  24763069  24813393     .      -     .
# 19163    chrY  BestRefSeq  transcript  24833919  24907040     .      +     .
# 19164    chrY  BestRefSeq  transcript  25030901  25052104     .      -     .
# 19165    chrY  BestRefSeq  transcript  25622117  25624902     .      +     .
#
#                                               attributes gene_id  \
# 0      gene_id "OR4F5"; transcript_id "NM_001005484.2...   OR4F5
# 1      gene_id "OR4F29"; transcript_id "NM_001005221....  OR4F29
# 2      gene_id "OR4F16"; transcript_id "NM_001005277....  OR4F16
# 3      gene_id "SAMD11"; transcript_id "NM_001385641....  SAMD11
# 4      gene_id "NOC2L"; transcript_id "NM_015658.4"; ...   NOC2L
# ...                                                  ...     ...
# 19161  gene_id "BPY2B"; transcript_id "NM_001002760.1...   BPY2B
# 19162  gene_id "DAZ3"; transcript_id "NM_020364.4"; d...    DAZ3
# 19163  gene_id "DAZ4"; transcript_id "NM_001388484.1"...    DAZ4
# 19164  gene_id "BPY2C"; transcript_id "NM_001002761.1...   BPY2C
# 19165  gene_id "CDY1"; transcript_id "NM_004680.3"; d...    CDY1
#
#         transcript_id  entrez_id
# 0      NM_001005484.2      79501
# 1      NM_001005221.2     729759
# 2      NM_001005277.1      81399
# 3      NM_001385641.1     148398
# 4         NM_015658.4      26155
# ...               ...        ...
# 19161  NM_001002760.1     442867
# 19162     NM_020364.4      57054
# 19163  NM_001388484.1      57135
# 19164  NM_001002761.1     442868
# 19165     NM_004680.3       9085
#
# [19166 rows x 12 columns]
